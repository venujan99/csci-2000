# %%
#Venujan Satchithanantham
#100600999

import numpy as np

#defining function for (1a)
def rho_n(n):
    result =0
    for k in range(1, n+1):
        result += 4*((-1)**(k+1))/(2*k - 1)
   
    return result

#defining function for (1b)
def tau_n(n):
    result = 0
    for k in range(1, n+1):
        result += (6*(1/k**2))
    result = result**(1/2)
    return result

#defining function for (1c)
def mu_n(n):
    result = 0
    for k in range(1, n+1):
        result += (90*(1/k**4))
    result = result**(1/4)
    return result


#printing approximation for when n=, in 11 decimal places
n = 10
result = rho_n(n)
print ("When n = %d, rho_n = %.11f " %(n,result))
n=10
result = tau_n(n)
print ("When n = %d, tau_n = %.11f " %(n,result))
n=10
result= mu_n(n)
print ("When n = %d, mu_n = %.11f " %(n,result))

#printing approximation for when n=100, in 11 decimal places
n = 100
result = rho_n(n)
print ("When n = %d, rho_n = %.11f " %(n,result))
n=100
result = tau_n(n)
print ("When n = %d, tau_n = %.11f " %(n,result))
n=100
result = mu_n(n)
print ("When n = %d,  mu_n = %.11f " %(n,result))

#printing approximation for when n=1000, in 11 decimal places
n = 1000
result = rho_n(n)
print ("When n = %d, rho_n = %.11f " %(n,result))
n=1000
result = tau_n(n)
print ("When n = %d, tau_n = %.11f " %(n,result))
n=1000
result = mu_n(n)
print ("When n = %d,  mu_n = %.11f " %(n,result))

#printing approximation for when n=10000, in 11 decimal places
n = 10000
result = rho_n(n)
print ("When n = %d, rho_n = %.11f " %(n,result))
n=10000
result = tau_n(n)
print ("When n = %d, tau_n = %.11f " %(n,result))
n=10000
result = mu_n(n)
print ("When n = %d,  mu_n = %.11f " %(n,result))

#printing approximation for when n=100000, in 11 decimal places
n = 100000
result = rho_n(n)
print ("When n = %d, rho_n = %.11f " %(n,result))
n=100000
result = tau_n(n)
print ("When n = %d, tau_n = %.11f " %(n,result))
n=100000
result = mu_n(n)
print ("When n = %d,  mu_n = %.11f " %(n,result))


#printing approximation for when n=1000000, in 11 decimal places
n = 1000000
result = rho_n(n)
print ("When n = %d, rho_n = %.11f " %(n,result))
n=1000000
result = tau_n(n)
print ("When n = %d, tau_n = %.11f " %(n,result))
n=1000000
result = mu_n(n)
print ("When n = %d,  mu_n = %.11f " %(n,result))
# Out:
# When n = 10, rho_n = 3.04183961893
# When n = 10, tau_n = 3.04936163598
# When n = 10, mu_n = 3.14138462247
# When n = 100, rho_n = 3.13159290356
# When n = 100, tau_n = 3.13207653181
# When n = 100,  mu_n = 3.14159241531
# When n = 1000, rho_n = 3.14059265384
# When n = 1000, tau_n = 3.14063805621
# When n = 1000,  mu_n = 3.14159265335
# When n = 10000, rho_n = 3.14149265359
# When n = 10000, tau_n = 3.14149716395
# When n = 10000,  mu_n = 3.14159265359
# When n = 100000, rho_n = 3.14158265359
# When n = 100000, tau_n = 3.14158310433
# When n = 100000,  mu_n = 3.14159265359
# When n = 1000000, rho_n = 3.14159165359
# When n = 1000000, tau_n = 3.14159169866
# When n = 1000000,  mu_n = 3.14159265359
